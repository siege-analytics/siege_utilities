# %% [markdown]
# # Census Data + Bivariate Choropleth Recipe
#
# This notebook demonstrates the complete workflow for:
#
# 1. **Census Boundary Download** with intelligent FIPS handling
# 2. **Thematic Data Integration** using Census APIs
# 3. **Dataset Recommendation System** for optimal data selection
# 4. **Bivariate Choropleth Mapping** with true 2D color schemes
#
# ## Prerequisites
#
# Install required dependencies:
# ```bash
# pip install pandas geopandas matplotlib requests folium
# ```

# %%
# Import siege utilities
import siege_utilities as su

# Check available Census functions
info = su.get_package_info()
su.log_info(info)
# Out:
# Importing logging from siege_utilities.core.logging
# Successfully imported 15 functions from logging
# Importing string_utils from siege_utilities.core.string_utils
# Successfully imported 1 functions from string_utils
# siege_utilities.core: Imported 16 functions
# [siege_utilities] 2025-09-12 14:45:45,451 WARNING: Failed to load user config: could not determine a constructor for the tag 'tag:yaml.org,2002:python/tuple'
#   in "/Users/dheerajchand/.siege_utilities/config/user_config.yaml", line 5, column 22
# [siege_utilities] 2025-09-12 14:45:45,454 INFO: Importing hdfs_operations from siege_utilities.distributed.hdfs_operations
# [siege_utilities] 2025-09-12 14:45:45,454 INFO: Successfully imported 2 functions from hdfs_operations
# [siege_utilities] 2025-09-12 14:45:45,455 INFO: Importing hdfs_config from siege_utilities.distributed.hdfs_config
# [siege_utilities] 2025-09-12 14:45:45,456 INFO: Successfully imported 5 functions from hdfs_config
# [siege_utilities] 2025-09-12 14:45:45,456 INFO: Importing hdfs_legacy from siege_utilities.distributed.hdfs_legacy
# INFO: Successfully imported 4 functions from hdfs_legacy
# INFO: Importing spark_utils from siege_utilities.distributed.spark_utils
# INFO: Successfully imported 478 functions from spark_utils
# INFO: siege_utilities.distributed: Imported 489 functions
# [siege_utilities] 2025-09-12 14:45:45,893 WARNING: SSL verification failed, trying without verification...
# [siege_utilities] 2025-09-12 14:45:46,230 INFO: Initialized Census data source with 23 available years
# [siege_utilities] 2025-09-12 14:45:46,233 INFO: DuckDB not available - using standard geospatial stack
# [siege_utilities] 2025-09-12 14:45:46,410 WARNING: Could not import additional analytics utilities: cannot import name 'get_dataset_metadata' from 'siege_utilities.analytics.datadotworld_connector' (/Users/dheerajchand/Desktop/in_process/code/siege_utilities_verify/siege_utilities/analytics/datadotworld_connector.py)
# [siege_utilities] 2025-09-12 14:45:47,121 WARNING: Could not import chart generation functions: cannot import name 'create_choropleth_map' from 'siege_utilities.reporting.chart_generator' (/Users/dheerajchand/Desktop/in_process/code/siege_utilities_verify/siege_utilities/reporting/chart_generator.py)
# INFO: Importing environment from siege_utilities.testing.environment
# INFO: Successfully imported 9 functions from environment
# INFO: Importing runner from siege_utilities.testing.runner
# INFO: Successfully imported 6 functions from runner
# INFO: Package info generated: 755 available functions, 0 unavailable
# INFO: {'package_name': 'siege_utilities', 'version': '1.0.0', 'description': 'Comprehensive utilities for data engineering, analytics, and distributed computing', 'total_functions': 755, 'available_functions': ['AbstractHDFSOperations', 'AnalyticsReportGenerator', 'AnalyzeArgument', 'AnalyzeResult', 'Any', 'ArrayType', 'BaseReportTemplate', 'BinaryType', 'BooleanType', 'ByteType', 'CalendarIntervalType', 'Callable', 'CharType', 'ChartGenerator', 'ClientBrandingManager', 'Column', 'DataFrame', 'DataType', 'DateType', 'DayTimeIntervalType', 'DecimalType', 'Dict', 'DoubleType', 'FacebookBusinessConnector', 'FloatType', 'GoogleAnalyticsConnector', 'HDFSConfig', 'IntegerType', 'List', 'LongType', 'MapType', 'NullType', 'Optional', 'OrderingColumn', 'PandasUDFType', 'PartitioningColumn', 'Path', 'PowerPointGenerator', 'ReportGenerator', 'Row', 'SelectedColumn', 'ShortType', 'SkipRestOfInputTableException', 'SparkSession', 'StringType', 'StructField', 'StructType', 'TimestampNTZType', 'TimestampType', 'Tuple', 'Union', 'UserConfigManager', 'UserDefinedFunction', 'UserDefinedTableFunction', 'UserProfile', 'VarcharType', 'VariantType', 'VariantVal', 'YearMonthIntervalType', 'abs', 'acos', 'acosh', 'add_months', 'aes_decrypt', 'aes_encrypt', 'aggregate', 'analyze_branch_status', 'analyze_class', 'analyze_function', 'analyze_function_signature', 'analyze_module', 'analyze_package_structure', 'any_value', 'apply_stash', 'approx_count_distinct', 'approx_percentile', 'array', 'array_agg', 'array_append', 'array_compact', 'array_contains', 'array_distinct', 'array_except', 'array_insert', 'array_intersect', 'array_join', 'array_max', 'array_min', 'array_position', 'array_prepend', 'array_remove', 'array_repeat', 'array_size', 'array_sort', 'array_union', 'arrays_overlap', 'arrays_zip', 'asc', 'asc_nulls_first', 'asc_nulls_last', 'ascii', 'asin', 'asinh', 'assert_true', 'associate_client_with_project', 'atan', 'atan2', 'atanh', 'atomic_write_with_staging', 'avg', 'backup_full_dataframe', 'base64', 'batch_retrieve_facebook_data', 'batch_retrieve_ga_data', 'bin', 'bit_and', 'bit_count', 'bit_get', 'bit_length', 'bit_or', 'bit_xor', 'bitmap_bit_position', 'bitmap_bucket_number', 'bitmap_construct_agg', 'bitmap_count', 'bitmap_or_agg', 'bitwise_not', 'bool_and', 'bool_or', 'broadcast', 'bround', 'btrim', 'bucket', 'calculate_file_hash', 'call_function', 'call_udf', 'cardinality', 'categorize_function', 'cbrt', 'ceil', 'ceiling', 'char', 'char_length', 'character_length', 'check_dependencies', 'check_hdfs_status', 'check_if_file_exists_at_path', 'cherry_pick_commit', 'clean_and_reorder_bbox', 'clean_empty_directories', 'clean_working_directory', 'cleanup_old_connections', 'coalesce', 'col', 'collate', 'collation', 'collect_list', 'collect_set', 'column', 'compare_census_datasets', 'compare_datasets', 'compute_walkability', 'concat', 'concat_ws', 'concatenate_addresses', 'configure_shared_logging', 'connect', 'construct_download_url', 'contains', 'conv', 'convert_timezone', 'copy_file', 'corr', 'cos', 'cosh', 'cot', 'count', 'count_distinct', 'count_if', 'count_lines', 'count_min_sketch', 'covar_pop', 'covar_samp', 'crc32', 'create_backup_path', 'create_bar_chart', 'create_bivariate_choropleth', 'create_choropleth_map', 'create_client_profile', 'create_cluster_config', 'create_connection_profile', 'create_dashboard', 'create_database_config', 'create_dataframe_summary_charts', 'create_dataset', 'create_directory_structure', 'create_facebook_account_profile', 'create_feature_branch', 'create_flow_map', 'create_ga_account_profile', 'create_geocoding_config', 'create_hdfs_config', 'create_hdfs_operations', 'create_heatmap', 'create_line_chart', 'create_local_config', 'create_map', 'create_marker_map', 'create_pie_chart', 'create_project_config', 'create_sample_dataset', 'create_scatter_plot', 'create_spark_session_with_databases', 'create_standard_project_structure', 'create_tag', 'create_unique_staging_directory', 'csc', 'cume_dist', 'curdate', 'curr ...

# %% [markdown]
# ## Step 1: FIPS Data Structure
#
# The unified FIPS data structure handles state identification intelligently:

# %%
# Demonstrate FIPS data structure (requires pandas)
try:
    # Get unified FIPS data
    fips_data = su.get_unified_fips_data()
    
    # Show examples
    for fips, info in list(fips_data.items())[:5]:
        print(f"FIPS {fips}: {info['name']} ({info['abbreviation']})")
        
    # Test state identifier normalization
    examples = ['CA', 'california', '6', 'Texas', 'NY']
    for example in examples:
        normalized = su.normalize_state_identifier(example)
        print(f"'{example}' -> {normalized}")
        
except ImportError as e:
    print(f"FIPS functions require pandas: {e}")
    print("Install with: pip install pandas")
# Out:
# FIPS 01: Alabama (AL)
# FIPS 02: Alaska (AK)
# FIPS 04: Arizona (AZ)
# FIPS 05: Arkansas (AR)
# FIPS 06: California (CA)
# 'CA' -> 06
# 'california' -> 06
# '6' -> None
# 'Texas' -> 48
# 'NY' -> 36

# %% [markdown]
# ## Step 2: Intelligent Census Dataset Selection
#
# The dataset recommendation system helps choose optimal Census data:

# %%
# Demonstrate dataset selection system
try:
    # Get dataset selector
    selector = su.get_census_data_selector()
    
    # Get recommendations for demographic analysis
    recommendations = su.select_census_datasets(
        analysis_type='demographics',
        geography_level='county',
        time_period='recent'
    )

    print("Primary recommendation:")
    primary = recommendations['primary_recommendation']
    print(f"  - {primary['dataset']}: Score {primary['suitability_score']}")
    print(f"    Breakdown: {primary['score_breakdown']}")
    print(f"    Rationale: {primary['rationale']}")

    print("\nAlternatives:")
    for alt in recommendations['alternatives']:
        print(f"  - {alt['dataset']}: Score {alt['suitability_score']}")
        print(f"    Breakdown: {alt['score_breakdown']}")
        print(f"    Rationale: {alt['rationale']}")
        
except ImportError as e:
    print(f"Dataset selection requires pandas: {e}")
except Exception as e:
    print(f"Dataset selection example: {e}")
# Out:
# Primary recommendation:
#   - ACS 5-Year Estimates (2020): Score 3.0
#     Breakdown: {'geography_match': 2.0, 'primary_dataset': 0.0, 'reliability_match': 1.0, 'time_period': 0.0, 'variable_coverage': 0.0, 'geography_preference': 0.0, 'total': 3.0}
#     Rationale: Meets reliability requirements; Provides detailed geographic coverage; 5-year estimates provide stable data for small areas
#
# Alternatives:
#   - ACS 1-Year Estimates (2020): Score 3.0
#     Breakdown: {'geography_match': 2.0, 'primary_dataset': 0.0, 'reliability_match': 1.0, 'time_period': 0.0, 'variable_coverage': 0.0, 'geography_preference': 0.0, 'total': 3.0}
#     Rationale: Alternative option with 3.0 suitability score

# %% [markdown]
# ## Step 3: Boundary Download with Year-Specific URLs
#
# The system handles Census Bureau's changing URL patterns:

# %%
# Demonstrate boundary download (requires geopandas)
try:
    # Download county boundaries for California
    boundaries = su.get_census_boundaries(
        year=2020,
        geographic_level='county',
        state_identifier='CA'  # Can use FIPS ('06'), abbreviation ('CA'), or name ('California')
    )
    
    print(f"✅ Downloaded {len(boundaries)} county boundaries")
    print(f"📋 Available columns: {list(boundaries.columns)}")
    
except ImportError as e:
    print(f"Boundary download requires geopandas: {e}")
    print("Install with: pip install geopandas")
except Exception as e:
    print(f"Boundary download error: {e}")
# Out:
# [siege_utilities] 2025-09-12 14:46:04,711 WARNING: SSL verification failed, trying without verification...
# [siege_utilities] 2025-09-12 14:46:05,141 INFO: Initialized Census data source with 23 available years
# [siege_utilities] 2025-09-12 14:46:05,141 INFO: Normalized '06' to FIPS 06: California (CA)
# [siege_utilities] 2025-09-12 14:46:05,254 WARNING: SSL verification failed for year 2020, trying without verification...
# [siege_utilities] 2025-09-12 14:46:05,426 INFO: Constructing URL for California (CA)
# [siege_utilities] 2025-09-12 14:46:05,427 INFO: Constructed URL: https://www2.census.gov/geo/tiger/TIGER2020/COUNTY/tl_2020_us_county.zip
# [siege_utilities] 2025-09-12 14:46:05,687 INFO: Downloading county boundaries for year 2020
# [siege_utilities] 2025-09-12 14:46:05,688 INFO: Downloading TIGER/Line data from: https://www2.census.gov/geo/tiger/TIGER2020/COUNTY/tl_2020_us_county.zip
# [siege_utilities] 2025-09-12 14:46:05,688 INFO: Ensured path exists: /Users/dheerajchand/Downloads/siege_utilities
# [siege_utilities] 2025-09-12 14:46:05,689 INFO: Generated local path: /Users/dheerajchand/Downloads/siege_utilities/tl_2020_us_county.zip
# [siege_utilities] 2025-09-12 14:46:05,689 INFO: Downloading https://www2.census.gov/geo/tiger/TIGER2020/COUNTY/tl_2020_us_county.zip to /Users/dheerajchand/Downloads/siege_utilities/tl_2020_us_county.zip
# [siege_utilities] 2025-09-12 14:46:05,820 INFO: Download started, file size: 80644766 bytes
# tl_2020_us_county.zip:  49%|####9     | 39.9M/80.6M [00:18<00:16, 2.54MB/s]

# %% [markdown]
# ## Step 4: Thematic Data Integration
#
# Combine Census boundaries with thematic data from APIs:

# %%
# Simulate thematic data (in practice, get from Census API)
import pandas as pd
import numpy as np

try:
    # Create sample thematic data
    np.random.seed(42)
    sample_data = pd.DataFrame({
        'GEOID': [f'06{str(i).zfill(3)}' for i in range(1, 59)],  # CA counties
        'population_density': np.random.lognormal(5, 1, 58),
        'median_income': np.random.normal(70000, 20000, 58)
    })
    
    print("Sample thematic data:")
    print(sample_data.head())
    
except Exception as e:
    print(f"Error creating sample data: {e}")

# %% [markdown]
# ## Step 5: True Bivariate Choropleth Mapping
#
# Create professional bivariate maps with proper 2D color schemes:

# %%
# Create bivariate choropleth map
try:
    # This function now uses true 2D color matrix
    bivariate_map = su.create_bivariate_choropleth(
        data=sample_data,
        geodata=boundaries,  # From step 3
        location_column='GEOID',
        value_column1='population_density',
        value_column2='median_income',
        title='Population Density vs Median Income',
        color_scheme='default'
    )
    
    print("Bivariate choropleth created successfully!")
    print("Features:")
    print("  - True 2D color matrix (not fake 1D colormap)")
    print("  - Quantile-based classification for both variables")
    print("  - Professional 3x3 legend grid")
    print("  - Proper bivariate color scheme")
    
except ImportError as e:
    print(f"Bivariate mapping requires matplotlib + geopandas: {e}")
    print("Install with: pip install matplotlib geopandas")

# %% [markdown]
# ## Step 6: Dataset Relationship Mapping
#
# Understand which Census datasets work well together:

# %%
# Explore dataset relationships
try:
    # Get dataset mapper
    mapper = su.get_census_dataset_mapper()
    
    # Find the best dataset for a specific analysis
    best_dataset = su.get_best_dataset_for_analysis(
        analysis_type='economic',
        geography_level='tract',
        time_sensitivity='current'
    )
    
    print(f"Best dataset for economic analysis: {best_dataset}")
    
    # Compare two datasets
    comparison = su.compare_census_datasets('acs_5yr', 'decennial')
    print(f"Dataset comparison: {comparison}")
    
except ImportError as e:
    print(f"Dataset mapping requires pandas: {e}")
except Exception as e:
    print(f"Dataset mapping example: {e}")

# %% [markdown]
# ## Summary: Complete Workflow
#
# This recipe demonstrates the complete Census + bivariate mapping workflow:
#
# ### 1. Intelligent FIPS Handling
# - Unified data structure with FIPS, name, and abbreviation
# - Smart state identifier normalization
# - Integrated FIPS validation in URL construction
#
# ### 2. Dataset Intelligence
# - Automatic dataset recommendations
# - Compatibility analysis between datasets
# - Analysis-type specific guidance
#
# ### 3. Robust Boundary Download
# - Year-specific URL pattern handling
# - Dynamic Census directory discovery
# - Graceful handling of URL changes
#
# ### 4. Professional Bivariate Mapping
# - True 2D color matrix (not fake 1D)
# - Proper quantile classification
# - 3x3 bivariate legend grid
#
# ### Key Improvements Made
#
# 1. **Fixed URL Construction**: Now handles Census Bureau's changing directory structures
# 2. **Unified FIPS Structure**: Single source of truth for state/territory identification
# 3. **True Bivariate Colors**: Replaced fake 1D colormap with proper 2D matrix
# 4. **Intelligent Dataset Selection**: Automated recommendations based on analysis needs
#
# The result is a professional-grade system for Census data analysis and visualization.
